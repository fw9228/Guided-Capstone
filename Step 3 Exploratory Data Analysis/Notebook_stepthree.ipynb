# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import statsmodels.formula.api as smf

from scipy.stats import norm
from scipy.stats import linregress

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\13134\\Documents\\GitHub\\Guided-Capstone\\Step 3 Exploratory Data Analysis'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 52EB-87F5
#
#  Directory of C:\Users\13134\Documents\GitHub\Guided-Capstone\Step 3 Exploratory Data Analysis
#
# 05/25/2020  10:48 AM    <DIR>          .
# 05/25/2020  10:48 AM    <DIR>          ..
# 05/18/2020  07:14 PM    <DIR>          .ipynb_checkpoints
# 05/25/2020  10:48 AM            26,568 Notebook_stepthree.ipynb
#                1 File(s)         26,568 bytes
#                3 Dir(s)  860,815,691,776 bytes free

# %%
#Load Step two data
filename = r'C:\Users\13134\Documents\GitHub\Guided-Capstone\Step 2 Data Wrangling\data\step2_output.csv'

df = pd.read_csv(filename)
df.head()
# Out:
#    Unnamed: 0                 Name   Region    state  summit_elev  \
# 0           0       Alyeska Resort   Alaska   Alaska         3939
# 1           1  Eaglecrest Ski Area   Alaska   Alaska         2600
# 2           2     Hilltop Ski Area   Alaska   Alaska         2090
# 3           3     Arizona Snowbowl  Arizona  Arizona        11500
# 4           4  Sunrise Park Resort  Arizona  Arizona        11100
#
#    vertical_drop  base_elev  trams  fastEight  fastSixes  ...  LongestRun_mi  \
# 0           2500        250      1        0.0          0  ...            1.0
# 1           1540       1200      0        0.0          0  ...            2.0
# 2            294       1796      0        0.0          0  ...            1.0
# 3           2300       9200      0        0.0          1  ...            2.0
# 4           1800       9200      0        0.0          0  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             0.0
# 2            30.0
# 3             0.0
# 4            80.0
#
# [5 rows x 28 columns]

# %%
#Deleting the Unnamed column

# del df['Unnamed: 0'] 

df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#                                   Name   Region    state  summit_elev  \
# 0                       Alyeska Resort   Alaska   Alaska         3939
# 1                  Eaglecrest Ski Area   Alaska   Alaska         2600
# 2                     Hilltop Ski Area   Alaska   Alaska         2090
# 3                     Arizona Snowbowl  Arizona  Arizona        11500
# 4                  Sunrise Park Resort  Arizona  Arizona        11100
# ..                                 ...      ...      ...          ...
# 325               Meadowlark Ski Lodge  Wyoming  Wyoming         9500
# 326          Sleeping Giant Ski Resort  Wyoming  Wyoming         7428
# 327                   Snow King Resort  Wyoming  Wyoming         7808
# 328  Snowy Range Ski & Recreation Area  Wyoming  Wyoming         9663
# 329                White Pine Ski Area  Wyoming  Wyoming         9500
#
#      vertical_drop  base_elev  trams  fastEight  fastSixes  fastQuads  ...  \
# 0             2500        250      1        0.0          0          2  ...
# 1             1540       1200      0        0.0          0          0  ...
# 2              294       1796      0        0.0          0          0  ...
# 3             2300       9200      0        0.0          1          0  ...
# 4             1800       9200      0        0.0          0          1  ...
# ..             ...        ...    ...        ...        ...        ...  ...
# 325           1000       8500      0        0.0          0          0  ...
# 326            810       6619      0        0.0          0          0  ...
# 327           1571       6237      0        0.0          0          0  ...
# 328            990       8798      0        0.0          0          0  ...
# 329           1100       8400      0        0.0          0          0  ...
#
#      LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# 0              1.0             1610.0      113.000000        150.000000
# 1              2.0              640.0       60.000000         45.000000
# 2              1.0               30.0       30.000000        150.000000
# 3              2.0              777.0      104.000000        122.000000
# 4              1.2              800.0       80.000000        115.000000
# ..             ...                ...             ...               ...
# 325            1.5              300.0      174.873239        115.103943
# 326            1.0              184.0       18.000000         61.000000
# 327            1.0              400.0      250.000000        121.000000
# 328            0.7               75.0       30.000000        131.000000
# 329            0.4              370.0      174.873239        115.103943
#
#      yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 0         60.0       669.000000     65.000000      85.00000
# 1         44.0       350.000000     47.000000      53.00000
# 2         36.0        69.000000     30.000000      34.00000
# 3         81.0       260.000000     89.000000      89.00000
# 4         49.0       250.000000     74.000000      78.00000
# ..         ...              ...           ...           ...
# 325        9.0       185.316456     57.916957      64.16681
# 326       81.0       310.000000     42.000000      42.00000
# 327       80.0       300.000000     59.000000      59.00000
# 328       59.0       250.000000     49.000000      49.00000
# 329       81.0       150.000000     57.916957      49.00000
#
#      projectedDaysOpen  NightSkiing_ac
# 0           150.000000           550.0
# 1            90.000000             0.0
# 2           152.000000            30.0
# 3           122.000000             0.0
# 4           104.000000            80.0
# ..                 ...             ...
# 325         120.053004             0.0
# 326          77.000000             0.0
# 327         123.000000           110.0
# 328         120.053004             0.0
# 329         120.053004             0.0
#
# [330 rows x 27 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0     0.003030     0.055048    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.214724    46.081366    3.0    19.00
# TerrainParks       330.0     2.820789     1.845918    1.0     2.00
# LongestRun_mi      330.0     1.433231     1.147352    0.0     0.60
# SkiableTerrain_ac  330.0   739.801223  1807.868079    8.0    85.00
# Snow Making_ac     330.0   174.873239   242.378848    2.0    55.00
# daysOpenLastYear   330.0   115.103943    32.231212    3.0   100.00
# yearsOpen          330.0    63.656535   109.263494    6.0    50.00
# averageSnowfall    330.0   185.316456   133.424094   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   120.053004    28.742976   30.0   101.25
# NightSkiing_ac     330.0    56.890909    93.464882    0.0     0.00
#
#                            50%          75%      max
# summit_elev        3127.500000  7806.000000  13487.0
# vertical_drop       964.500000  1800.000000   4425.0
# base_elev          1561.500000  6325.250000  10800.0
# trams                 0.000000     0.000000      4.0
# fastEight             0.000000     0.000000      1.0
# fastSixes             0.000000     0.000000      6.0
# fastQuads             0.000000     1.000000     15.0
# quad                  0.000000     1.000000      8.0
# triple                1.000000     2.000000      8.0
# double                1.000000     3.000000     14.0
# surface               2.000000     3.000000     15.0
# total_chairs          7.000000    10.000000     41.0
# Runs                 34.000000    60.000000    341.0
# TerrainParks          2.820789     3.000000     14.0
# LongestRun_mi         1.000000     2.000000      6.0
# SkiableTerrain_ac   200.000000   739.801223  26819.0
# Snow Making_ac      132.500000   192.000000   3379.0
# daysOpenLastYear    115.103943   130.000000    305.0
# yearsOpen            58.000000    68.750000   2019.0
# averageSnowfall     158.000000   278.750000    669.0
# AdultWeekday         57.916957    67.000000    179.0
# AdultWeekend         64.166810    72.000000    179.0
# projectedDaysOpen   120.053004   136.000000    305.0
# NightSkiing_ac       27.000000    83.750000    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
df.plot(kind='hist', bins=25, figsize=(12,15))

# %%
df.hist(bins=25,figsize=(15,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F18101C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2406508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2412E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2428F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F24720C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F1F8B1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F1FC22C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F1FFB3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2000F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2041148>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F20A4708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F20DD788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2117888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F21519C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F218AAC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F21C1BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F21FAC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2233D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F226AE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F22A2FC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F22DF108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F27191C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F2753308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F278B408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000237F27C4508>]],
#       dtype=object)

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %%
df['state'].value_counts().plot(kind='bar')

# %%
df['Region'].value_counts().plot(kind='bar')

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions! 

f, ax = plt.subplots(figsize=(10, 10))

x = pd.DataFrame(df.Region.value_counts())


names = list(x.index)


values = list(x.Region)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
#Deleting region

# df.drop('Region', axis=1, inplace=True)

del df['Region']

df.head()
# Out:
#                   Name    state  summit_elev  vertical_drop  base_elev  trams  \
# 0       Alyeska Resort   Alaska         3939           2500        250      1
# 1  Eaglecrest Ski Area   Alaska         2600           1540       1200      0
# 2     Hilltop Ski Area   Alaska         2090            294       1796      0
# 3     Arizona Snowbowl  Arizona        11500           2300       9200      0
# 4  Sunrise Park Resort  Arizona        11100           1800       9200      0
#
#    fastEight  fastSixes  fastQuads  quad  ...  LongestRun_mi  \
# 0        0.0          0          2     2  ...            1.0
# 1        0.0          0          0     0  ...            2.0
# 2        0.0          0          0     0  ...            1.0
# 3        0.0          1          0     2  ...            2.0
# 4        0.0          0          1     2  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1             0.0
# 2            30.0
# 3             0.0
# 4            80.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
df.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

dfno = df[~((df < (Q1 - 1.5*IQR)) |(df> (Q3 + 1.5*IQR))).any(axis=1)]

boxplot = df.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
df.shape
# Out:
# (167, 26)

# %%
dfno.shape
# Out:
# (99, 26)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
plt.hist(dfno['AdultWeekday'],bins=15)
plt.xlabel('Cost of An Adult Weekday Chairlift Ticket')
# Out:
# Text(0.5, 0, 'Cost of An Adult Weekday Chairlift Ticket')

# %%
#We can put a line through the histogram above as below using sns
sns.distplot(dfno['AdultWeekday'], bins=15)
plt.xlabel('Cost of An Adult Weekday Chairlift Ticket')
# Out:
# Text(0.5, 0, 'Cost of An Adult Weekday Chairlift Ticket')

# %%
# Do the same but with the AdultWeekend column 
sns.distplot(dfno['AdultWeekend'], bins=15)
plt.xlabel('Cost of An Adult Weekend Chairlift Ticket')
# Out:
# Text(0.5, 0, 'Cost of An Adult Weekend Chairlift Ticket')

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :) 
sns.distplot(dfno['daysOpenLastYear'], bins=15)
plt.xlabel('Total number of days open last year')
# Out:
# Text(0.5, 0, 'Total number of days open last year')

# %%
sns.distplot(dfno['projectedDaysOpen'], bins=15)
plt.xlabel('Projected days open in the upcoming season')
# Out:
# Text(0.5, 0, 'Projected days open in the upcoming season')

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
df.describe().T
# Out:
#                    count         mean          std    min     25%     50%  \
# summit_elev        167.0  3603.856287  3236.111943  315.0  1240.0  2000.0
# vertical_drop      167.0   835.497006   583.574495  175.0   357.5   650.0
# base_elev          167.0  2756.449102  2880.513957   70.0   756.0  1250.0
# trams              167.0     0.000000     0.000000    0.0     0.0     0.0
# fastEight          167.0     0.000000     0.000000    0.0     0.0     0.0
# fastSixes          167.0     0.000000     0.000000    0.0     0.0     0.0
# fastQuads          167.0     0.221557     0.563992    0.0     0.0     0.0
# quad               167.0     0.538922     0.709221    0.0     0.0     0.0
# triple             167.0     1.125749     1.172885    0.0     0.0     1.0
# double             167.0     1.658683     1.374345    0.0     1.0     1.0
# surface            167.0     2.221557     1.420170    0.0     1.0     2.0
# total_chairs       167.0     5.766467     2.485975    0.0     4.0     5.0
# Runs               167.0    29.335329    17.148751    7.0    15.5    24.0
# TerrainParks       167.0     2.122422     0.942253    1.0     1.0     2.0
# LongestRun_mi      167.0     0.982434     0.723295    0.0     0.4     1.0
# SkiableTerrain_ac  167.0   243.106594   322.663730   15.0    50.0   115.0
# Snow Making_ac     167.0   102.222063    68.306294   13.0    43.5    84.0
# daysOpenLastYear   167.0   105.653403    21.946731   56.0    93.0   110.0
# yearsOpen          167.0    59.219500    14.330361   22.0    51.0    58.0
# averageSnowfall    167.0   144.975442   104.562439   18.0    53.5   120.0
# AdultWeekday       167.0    49.848378    15.831880   20.0    39.0    49.0
# AdultWeekend       167.0    56.406439    15.305689   20.0    45.0    55.0
# projectedDaysOpen  167.0   111.702545    20.862934   56.0   100.0   115.0
# NightSkiing_ac     167.0    41.634731    43.794339    0.0     0.0    35.0
#
#                            75%      max
# summit_elev        5779.500000  12075.0
# vertical_drop      1150.000000   2600.0
# base_elev          4522.500000  10790.0
# trams                 0.000000      0.0
# fastEight             0.000000      0.0
# fastSixes             0.000000      0.0
# fastQuads             0.000000      2.0
# quad                  1.000000      2.0
# triple                2.000000      5.0
# double                2.000000      6.0
# surface               3.000000      6.0
# total_chairs          7.000000     14.0
# Runs                 41.500000     83.0
# TerrainParks          2.820789      4.0
# LongestRun_mi         1.433231      4.0
# SkiableTerrain_ac   245.000000   1704.0
# Snow Making_ac      174.873239    300.0
# daysOpenLastYear    115.103943    163.0
# yearsOpen            67.500000     95.0
# averageSnowfall     207.000000    500.0
# AdultWeekday         57.916957     89.0
# AdultWeekend         65.000000     93.0
# projectedDaysOpen   120.053004    180.0
# NightSkiing_ac       69.500000    180.0

# %%
dfno.describe().T
# Out:
#                    count         mean          std    min      25%     50%  \
# summit_elev         99.0  2868.434343  2752.885055  315.0  1123.50  1620.0
# vertical_drop       99.0   661.484848   446.264733  175.0   309.50   515.0
# base_elev           99.0  2189.060606  2441.689286   70.0   640.50  1120.0
# trams               99.0     0.000000     0.000000    0.0     0.00     0.0
# fastEight           99.0     0.000000     0.000000    0.0     0.00     0.0
# fastSixes           99.0     0.000000     0.000000    0.0     0.00     0.0
# fastQuads           99.0     0.000000     0.000000    0.0     0.00     0.0
# quad                99.0     0.505051     0.719605    0.0     0.00     0.0
# triple              99.0     1.090909     1.187442    0.0     0.00     1.0
# double              99.0     1.212121     0.939743    0.0     0.50     1.0
# surface             99.0     2.343434     1.429725    0.0     1.00     2.0
# total_chairs        99.0     5.151515     1.934455    2.0     4.00     5.0
# Runs                99.0    23.404040    13.455080    7.0    13.50    22.0
# TerrainParks        99.0     2.099779     0.923112    1.0     1.00     2.0
# LongestRun_mi       99.0     0.735015     0.546920    0.0     0.30     0.5
# SkiableTerrain_ac   99.0   114.717172   106.146033   15.0    45.00    80.0
# Snow Making_ac      99.0    82.371034    57.125422   13.0    40.00    60.0
# daysOpenLastYear    99.0   102.889685    19.728748   60.0    90.50   105.0
# yearsOpen           99.0    59.626263    13.226894   33.0    52.00    58.0
# averageSnowfall     99.0   120.133998    87.181559   20.0    50.00   100.0
# AdultWeekday        99.0    45.899943    13.142412   20.0    35.67    45.0
# AdultWeekend        99.0    52.919274    12.876258   30.0    44.00    50.0
# projectedDaysOpen   99.0   107.747011    16.668010   70.0   100.00   110.0
# NightSkiing_ac      99.0    43.171717    37.717543    0.0     6.00    40.0
#
#                            75%      max
# summit_elev        3618.500000  11289.0
# vertical_drop       855.000000   2150.0
# base_elev          2748.500000   8798.0
# trams                 0.000000      0.0
# fastEight             0.000000      0.0
# fastSixes             0.000000      0.0
# fastQuads             0.000000      0.0
# quad                  1.000000      2.0
# triple                2.000000      5.0
# double                2.000000      3.0
# surface               3.000000      6.0
# total_chairs          6.000000     11.0
# Runs                 28.500000     71.0
# TerrainParks          2.820789      4.0
# LongestRun_mi         1.000000      2.5
# SkiableTerrain_ac   139.500000    500.0
# Snow Making_ac      108.500000    250.0
# daysOpenLastYear    115.103943    144.0
# yearsOpen            66.500000     85.0
# averageSnowfall     168.000000    400.0
# AdultWeekday         57.916957     80.0
# AdultWeekend         64.166810     92.0
# projectedDaysOpen   120.053004    150.0
# NightSkiing_ac       67.500000    150.0

# %%
sns.pairplot(dfno, vars=['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'])

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno[['AdultWeekday','AdultWeekend','daysOpenLastYear', 'projectedDaysOpen']].corr(method ='pearson')

#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col1 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col0 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col3 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col0 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AdultWeekday</th>        <th class="col_heading level0 col1" >AdultWeekend</th>        <th class="col_heading level0 col2" >daysOpenLastYear</th>        <th class="col_heading level0 col3" >projectedDaysOpen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6alevel0_row0" class="row_heading level0 row0" >AdultWeekday</th>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col1" class="data row0 col1" >0.720000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col2" class="data row0 col2" >0.100000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow0_col3" class="data row0 col3" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6alevel0_row1" class="row_heading level0 row1" >AdultWeekend</th>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col0" class="data row1 col0" >0.720000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col2" class="data row1 col2" >0.130000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow1_col3" class="data row1 col3" >0.140000</td>
#             </tr>
#             <tr>
#                         <th id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6alevel0_row2" class="row_heading level0 row2" >daysOpenLastYear</th>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col0" class="data row2 col0" >0.100000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col1" class="data row2 col1" >0.130000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow2_col3" class="data row2 col3" >0.680000</td>
#             </tr>
#             <tr>
#                         <th id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6alevel0_row3" class="row_heading level0 row3" >projectedDaysOpen</th>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col0" class="data row3 col0" >0.200000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col1" class="data row3 col1" >0.140000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col2" class="data row3 col2" >0.680000</td>
#                         <td id="T_658c821a_9e9a_11ea_843b_b0fc36a8ba6arow3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %%
#Heat map
Corr_map = dfno.corr()

sns.heatmap(Corr_map)

# %%
Corr_map
# Out:
#                    summit_elev  vertical_drop  base_elev  trams  fastEight  \
# summit_elev           1.000000       0.648493   0.989576    NaN        NaN
# vertical_drop         0.648493       1.000000   0.548899    NaN        NaN
# base_elev             0.989576       0.548899   1.000000    NaN        NaN
# trams                      NaN            NaN        NaN    NaN        NaN
# fastEight                  NaN            NaN        NaN    NaN        NaN
# fastSixes                  NaN            NaN        NaN    NaN        NaN
# fastQuads                  NaN            NaN        NaN    NaN        NaN
# quad                  0.033802       0.009938   0.019676    NaN        NaN
# triple                0.081923       0.150133   0.067786    NaN        NaN
# double               -0.060116       0.094500  -0.074054    NaN        NaN
# surface              -0.457059      -0.432457  -0.424308    NaN        NaN
# total_chairs         -0.304148      -0.177861  -0.300645    NaN        NaN
# Runs                  0.438620       0.732080   0.364706    NaN        NaN
# TerrainParks         -0.047890      -0.055162  -0.034557    NaN        NaN
# LongestRun_mi         0.263997       0.472532   0.219400    NaN        NaN
# SkiableTerrain_ac     0.640989       0.734154   0.588340    NaN        NaN
# Snow Making_ac        0.401957       0.507119   0.365732    NaN        NaN
# daysOpenLastYear      0.259095       0.264720   0.228994    NaN        NaN
# yearsOpen             0.148430       0.175290   0.135294    NaN        NaN
# averageSnowfall       0.633894       0.624535   0.602063    NaN        NaN
# AdultWeekday          0.290860       0.453574   0.233813    NaN        NaN
# AdultWeekend          0.154945       0.438813   0.085370    NaN        NaN
# projectedDaysOpen     0.190639       0.254251   0.149321    NaN        NaN
# NightSkiing_ac       -0.405424      -0.202682  -0.413525    NaN        NaN
#
#                    fastSixes  fastQuads      quad    triple    double  ...  \
# summit_elev              NaN        NaN  0.033802  0.081923 -0.060116  ...
# vertical_drop            NaN        NaN  0.009938  0.150133  0.094500  ...
# base_elev                NaN        NaN  0.019676  0.067786 -0.074054  ...
# trams                    NaN        NaN       NaN       NaN       NaN  ...
# fastEight                NaN        NaN       NaN       NaN       NaN  ...
# fastSixes                NaN        NaN       NaN       NaN       NaN  ...
# fastQuads                NaN        NaN       NaN       NaN       NaN  ...
# quad                     NaN        NaN  1.000000  0.065137 -0.356200  ...
# triple                   NaN        NaN  0.065137  1.000000 -0.264355  ...
# double                   NaN        NaN -0.356200 -0.264355  1.000000  ...
# surface                  NaN        NaN  0.186740 -0.012567 -0.183884  ...
# total_chairs             NaN        NaN  0.376955  0.500359  0.055111  ...
# Runs                     NaN        NaN  0.072505  0.188001  0.121467  ...
# TerrainParks             NaN        NaN  0.024230  0.094741 -0.001122  ...
# LongestRun_mi            NaN        NaN -0.022927  0.169981 -0.028496  ...
# SkiableTerrain_ac        NaN        NaN  0.015382  0.189647 -0.021284  ...
# Snow Making_ac           NaN        NaN -0.019778  0.289938  0.016314  ...
# daysOpenLastYear         NaN        NaN  0.228169 -0.061990  0.063962  ...
# yearsOpen                NaN        NaN -0.187947 -0.219358  0.208392  ...
# averageSnowfall          NaN        NaN -0.164339  0.082580  0.127227  ...
# AdultWeekday             NaN        NaN  0.108543  0.264150  0.067209  ...
# AdultWeekend             NaN        NaN  0.186168  0.323607  0.102759  ...
# projectedDaysOpen        NaN        NaN  0.162599  0.059323  0.050538  ...
# NightSkiing_ac           NaN        NaN  0.192645  0.238190  0.072085  ...
#
#                    LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# summit_elev             0.263997           0.640989        0.401957
# vertical_drop           0.472532           0.734154        0.507119
# base_elev               0.219400           0.588340        0.365732
# trams                        NaN                NaN             NaN
# fastEight                    NaN                NaN             NaN
# fastSixes                    NaN                NaN             NaN
# fastQuads                    NaN                NaN             NaN
# quad                   -0.022927           0.015382       -0.019778
# triple                  0.169981           0.189647        0.289938
# double                 -0.028496          -0.021284        0.016314
# surface                -0.084269          -0.389605       -0.309810
# total_chairs            0.019687          -0.176156       -0.050433
# Runs                    0.515231           0.639974        0.353992
# TerrainParks            0.009776          -0.004831        0.104918
# LongestRun_mi           1.000000           0.397504        0.387522
# SkiableTerrain_ac       0.397504           1.000000        0.667958
# Snow Making_ac          0.387522           0.667958        1.000000
# daysOpenLastYear       -0.056454           0.132011        0.118593
# yearsOpen               0.038879           0.186194        0.273261
# averageSnowfall         0.221563           0.671238        0.442691
# AdultWeekday            0.190870           0.345168        0.315644
# AdultWeekend            0.258860           0.205922        0.216020
# projectedDaysOpen       0.019978           0.187757        0.195349
# NightSkiing_ac         -0.035715          -0.084502        0.250788
#
#                    daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekday  \
# summit_elev                0.259095   0.148430         0.633894      0.290860
# vertical_drop              0.264720   0.175290         0.624535      0.453574
# base_elev                  0.228994   0.135294         0.602063      0.233813
# trams                           NaN        NaN              NaN           NaN
# fastEight                       NaN        NaN              NaN           NaN
# fastSixes                       NaN        NaN              NaN           NaN
# fastQuads                       NaN        NaN              NaN           NaN
# quad                       0.228169  -0.187947        -0.164339      0.108543
# triple                    -0.061990  -0.219358         0.082580      0.264150
# double                     0.063962   0.208392         0.127227      0.067209
# surface                   -0.115191  -0.205742        -0.378868     -0.234960
# total_chairs              -0.007239  -0.255390        -0.228652      0.061517
# Runs                       0.196750   0.147695         0.543097      0.427950
# TerrainParks              -0.064901   0.114964        -0.024986     -0.109028
# LongestRun_mi             -0.056454   0.038879         0.221563      0.190870
# SkiableTerrain_ac          0.132011   0.186194         0.671238      0.345168
# Snow Making_ac             0.118593   0.273261         0.442691      0.315644
# daysOpenLastYear           1.000000   0.140401         0.216995      0.098071
# yearsOpen                  0.140401   1.000000         0.229897     -0.190035
# averageSnowfall            0.216995   0.229897         1.000000      0.232900
# AdultWeekday               0.098071  -0.190035         0.232900      1.000000
# AdultWeekend               0.131999  -0.136752         0.082879      0.717674
# projectedDaysOpen          0.679168   0.067902         0.278886      0.201017
# NightSkiing_ac            -0.028564  -0.002386        -0.187941      0.036564
#
#                    AdultWeekend  projectedDaysOpen  NightSkiing_ac
# summit_elev            0.154945           0.190639       -0.405424
# vertical_drop          0.438813           0.254251       -0.202682
# base_elev              0.085370           0.149321       -0.413525
# trams                       NaN                NaN             NaN
# fastEight                   NaN                NaN             NaN
# fastSixes                   NaN                NaN             NaN
# fastQuads                   NaN                NaN             NaN
# quad                   0.186168           0.162599        0.192645
# triple                 0.323607           0.059323        0.238190
# double                 0.102759           0.050538        0.072085
# surface               -0.204199          -0.139693        0.151789
# total_chairs           0.166895           0.018206        0.365076
# Runs                   0.457124           0.232690       -0.058609
# TerrainParks          -0.042344           0.086806        0.038716
# LongestRun_mi          0.258860           0.019978       -0.035715
# SkiableTerrain_ac      0.205922           0.187757       -0.084502
# Snow Making_ac         0.216020           0.195349        0.250788
# daysOpenLastYear       0.131999           0.679168       -0.028564
# yearsOpen             -0.136752           0.067902       -0.002386
# averageSnowfall        0.082879           0.278886       -0.187941
# AdultWeekday           0.717674           0.201017        0.036564
# AdultWeekend           1.000000           0.140705        0.107183
# projectedDaysOpen      0.140705           1.000000        0.045575
# NightSkiing_ac         0.107183           0.045575        1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (99, 25)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno.drop(dfno[to_drop], axis=1)
# Out:
#                                   Name        state  summit_elev  \
# 5        Yosemite Ski & Snowboard Area   California         7800
# 15                 Mt. Shasta Ski Park   California         6890
# 48                     Mohawk Mountain  Connecticut         1600
# 49          Mount Southington Ski Area  Connecticut          525
# 50                   Powder Ridge Park  Connecticut          720
# ..                                 ...          ...          ...
# 323                      Hogadon Basin      Wyoming         8000
# 326          Sleeping Giant Ski Resort      Wyoming         7428
# 327                   Snow King Resort      Wyoming         7808
# 328  Snowy Range Ski & Recreation Area      Wyoming         9663
# 329                White Pine Ski Area      Wyoming         9500
#
#      vertical_drop  trams  fastEight  fastSixes  fastQuads  quad  triple  ...  \
# 5              600      0        0.0          0          0     0       1  ...
# 15            1435      0        0.0          0          0     0       3  ...
# 48             650      0        0.0          0          0     0       5  ...
# 49             425      0        0.0          0          0     0       2  ...
# 50             550      0        0.0          0          0     0       1  ...
# ..             ...    ...        ...        ...        ...   ...     ...  ...
# 323            640      0        0.0          0          0     0       0  ...
# 326            810      0        0.0          0          0     0       1  ...
# 327           1571      0        0.0          0          0     1       1  ...
# 328            990      0        0.0          0          0     0       1  ...
# 329           1100      0        0.0          0          0     0       2  ...
#
#      LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# 5              0.4               88.0      174.873239        110.000000
# 15             1.1              425.0      225.000000        140.000000
# 48             1.5              107.0      100.000000        115.103943
# 49             0.3               51.0       51.000000         63.000000
# 50             0.5               80.0       68.000000         80.000000
# ..             ...                ...             ...               ...
# 323            0.6               92.0       32.000000        121.000000
# 326            1.0              184.0       18.000000         61.000000
# 327            1.0              400.0      250.000000        121.000000
# 328            0.7               75.0       30.000000        131.000000
# 329            0.4              370.0      174.873239        115.103943
#
#      yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# 5         84.0            300.0     47.000000          47.0
# 15        34.0            300.0     49.000000          59.0
# 48        72.0             92.0     30.000000          65.0
# 49        55.0             80.0     60.000000          60.0
# 50        60.0             80.0     45.000000          55.0
# ..         ...              ...           ...           ...
# 323       61.0             80.0     48.000000          48.0
# 326       81.0            310.0     42.000000          42.0
# 327       80.0            300.0     59.000000          59.0
# 328       59.0            250.0     49.000000          49.0
# 329       81.0            150.0     57.916957          49.0
#
#      projectedDaysOpen  NightSkiing_ac
# 5           107.000000             0.0
# 15          130.000000             0.0
# 48          110.000000            64.0
# 49           95.000000            51.0
# 50          100.000000            40.0
# ..                 ...             ...
# 323          95.000000             0.0
# 326          77.000000             0.0
# 327         123.000000           110.0
# 328         120.053004             0.0
# 329         120.053004             0.0
#
# [99 rows x 25 columns]

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
c = pd.DataFrame(y_kmeans3, columns=['clusters']).set_index(dfno.index)
dfno = pd.concat([df, c], axis=1)

# %%
#Create a folder called Data
os.mkdir('data')

# %%
# Write your dataframe to csv 


dfno.to_csv(os.getcwd() + r'\data\step3_output.csv')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 52EB-87F5
#
#  Directory of C:\Users\13134\Documents\GitHub\Guided-Capstone\Step 3 Exploratory Data Analysis
#
# 05/25/2020  11:50 AM    <DIR>          .
# 05/25/2020  11:50 AM    <DIR>          ..
# 05/18/2020  07:14 PM    <DIR>          .ipynb_checkpoints
# 05/25/2020  11:50 AM    <DIR>          data
# 05/25/2020  11:50 AM           758,281 Notebook_stepthree.ipynb
#                1 File(s)        758,281 bytes
#                4 Dir(s)  860,818,743,296 bytes free
